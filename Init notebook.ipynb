# %% [markdown]
# ## Initialization Notebook
# This is your initialization notebook.
#
# **What's this for?**
#
# You can put custom code you want us to run every time we setup your environment in here.
#
# **Awesome! Anything I should not put in here?**
#
# Please don't install `jupyter` or `jedi` packages, they would break your Deepnote environment. Also, no need to put `!pip install`s here, we already save those automatically!
#
# **I want to learn more!**
#
# Great! Just [head over to our docs](https://deepnote.com/docs/custom-initialization).

# %%
# %%bash
# # If your project has a 'requirements.txt' file, we'll install it here apart from blacklisted packages that interfere with Deepnote (see above).
# if test -f requirements.txt
#   then
#     sed -i '/jedi/d;/jupyter/d;' ./requirements.txt
#     pip install -r ./requirements.txt
#   else echo "There's no requirements.txt, so nothing to install. This is the case with most projects."
# fi
# Out:
# Requirement already satisfied: missingno in /root/venv/lib/python3.9/site-packages (from -r ./requirements.txt (line 1)) (0.5.1)
# Requirement already satisfied: wordcloud in /root/venv/lib/python3.9/site-packages (from -r ./requirements.txt (line 2)) (1.8.2.2)
# Requirement already satisfied: openpyxl in /root/venv/lib/python3.9/site-packages (from -r ./requirements.txt (line 3)) (3.0.10)
# Requirement already satisfied: folium in /shared-libs/python3.9/py/lib/python3.9/site-packages (from -r ./requirements.txt (line 4)) (0.13.0)
# Requirement already satisfied: matplotlib in /shared-libs/python3.9/py/lib/python3.9/site-packages (from -r ./requirements.txt (line 5)) (3.6.0)
# Requirement already satisfied: mapclassify in /root/venv/lib/python3.9/site-packages (from -r ./requirements.txt (line 6)) (2.4.3)
# Requirement already satisfied: pip in /root/venv/lib/python3.9/site-packages (from -r ./requirements.txt (line 7)) (22.0.4)
# Requirement already satisfied: xgboost==1.7.1 in /root/venv/lib/python3.9/site-packages (from -r ./requirements.txt (line 8)) (1.7.1)
# Requirement already satisfied: gradio in /root/venv/lib/python3.9/site-packages (from -r ./requirements.txt (line 9)) (3.15.0)
# Requirement already satisfied: pandas==1.4.2 in /root/venv/lib/python3.9/site-packages (from -r ./requirements.txt (line 10)) (1.4.2)
# Requirement already satisfied: numpy in /shared-libs/python3.9/py/lib/python3.9/site-packages (from xgboost==1.7.1->-r ./requirements.txt (line 8)) (1.23.4)
# Requirement already satisfied: scipy in /shared-libs/python3.9/py/lib/python3.9/site-packages (from xgboost==1.7.1->-r ./requirements.txt (line 8)) (1.9.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from pandas==1.4.2->-r ./requirements.txt (line 10)) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from pandas==1.4.2->-r ./requirements.txt (line 10)) (2022.5)
# Requirement already satisfied: seaborn in /shared-libs/python3.9/py/lib/python3.9/site-packages (from missingno->-r ./requirements.txt (line 1)) (0.12.1)
# Requirement already satisfied: pillow in /shared-libs/python3.9/py/lib/python3.9/site-packages (from wordcloud->-r ./requirements.txt (line 2)) (9.2.0)
# Requirement already satisfied: et-xmlfile in /root/venv/lib/python3.9/site-packages (from openpyxl->-r ./requirements.txt (line 3)) (1.1.0)
# Requirement already satisfied: requests in /shared-libs/python3.9/py/lib/python3.9/site-packages (from folium->-r ./requirements.txt (line 4)) (2.28.1)
# Requirement already satisfied: jinja2>=2.9 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from folium->-r ./requirements.txt (line 4)) (2.11.3)
# Requirement already satisfied: branca>=0.3.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from folium->-r ./requirements.txt (line 4)) (0.5.0)
# Requirement already satisfied: fonttools>=4.22.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from matplotlib->-r ./requirements.txt (line 5)) (4.37.4)
# Requirement already satisfied: contourpy>=1.0.1 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from matplotlib->-r ./requirements.txt (line 5)) (1.0.5)
# Requirement already satisfied: pyparsing>=2.2.1 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from matplotlib->-r ./requirements.txt (line 5)) (3.0.9)
# Requirement already satisfied: cycler>=0.10 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from matplotlib->-r ./requirements.txt (line 5)) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from matplotlib->-r ./requirements.txt (line 5)) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from matplotlib->-r ./requirements.txt (line 5)) (21.3)
# Requirement already satisfied: scikit-learn in /shared-libs/python3.9/py/lib/python3.9/site-packages (from mapclassify->-r ./requirements.txt (line 6)) (1.1.2)
# Requirement already satisfied: networkx in /root/venv/lib/python3.9/site-packages (from mapclassify->-r ./requirements.txt (line 6)) (2.8.8)
# Requirement already satisfied: aiohttp in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from gradio->-r ./requirements.txt (line 9)) (3.8.3)
# Requirement already satisfied: pydub in /root/venv/lib/python3.9/site-packages (from gradio->-r ./requirements.txt (line 9)) (0.25.1)
# Requirement already satisfied: pyyaml in /root/venv/lib/python3.9/site-packages (from gradio->-r ./requirements.txt (line 9)) (6.0)
# Requirement already satisfied: pydantic in /shared-libs/python3.9/py/lib/python3.9/site-packages (from gradio->-r ./requirements.txt (line 9)) (1.10.2)
# Requirement already satisfied: orjson in /root/venv/lib/python3.9/site-packages (from gradio->-r ./requirements.txt (line 9)) (3.8.3)
# Requirement already satisfied: fsspec in /root/venv/lib/python3.9/site-packages (from gradio->-r ./requirements.txt (line 9)) (2022.11.0)
# Requirement already satisfied: httpx in /root/venv/lib/python3.9/site-packages (from gradio->-r ./requirements.txt (line 9)) (0.23.1)
# Requirement already satisfied: uvicorn in /root/venv/lib/python3.9/site-packages (from gradio->-r ./requirements.txt (line 9)) (0.20.0)
# Requirement already satisfied: fastapi in /root/venv/lib/python3.9/site-packages (from gradio->-r ./requirements.txt (line 9)) (0.88.0)
# Requirement already satisfied: markdown-it-py[linkify,plugins] in /root/venv/lib/python3.9/site-packages (from gradio->-r ./requirements.txt (line 9)) (2.1.0)
# Requirement already satisfied: altair>=4.2.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from gradio->-r ./requirements.txt (line 9)) (4.2.0)
# Requirement already satisfied: websockets>=10.0 in /root/venv/lib/python3.9/site-packages (from gradio->-r ./requirements.txt (line 9)) (10.4)
# Requirement already satisfied: pycryptodome in /root/venv/lib/python3.9/site-packages (from gradio->-r ./requirements.txt (line 9)) (3.16.0)
# Requirement already satisfied: ffmpy in /root/venv/lib/python3.9/site-packages (from gradio->-r ./requirements.txt (line 9)) (0.3.0)
# Requirement already satisfied: markupsafe in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from gradio->-r ./requirements.txt (line 9)) (2.0.1)
# Requirement already satisfied: python-multipart in /root/venv/lib/python3.9/site-packages (from gradio->-r ./requirements.txt (line 9)) (0.0.5)
# Requirement already satisfied: toolz in /shared-libs/python3.9/py/lib/python3.9/site-packages (from altair>=4.2.0->gradio->-r ./requirements.txt (line 9)) (0.12.0)
# Requirement already satisfied: jsonschema>=3.0 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from altair>=4.2.0->gradio->-r ./requirements.txt (line 9)) (3.2.0)
# Requirement already satisfied: entrypoints in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from altair>=4.2.0->gradio->-r ./requirements.txt (line 9)) (0.4)
# Requirement already satisfied: six>=1.5 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from python-dateutil>=2.8.1->pandas==1.4.2->-r ./requirements.txt (line 10)) (1.16.0)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from aiohttp->gradio->-r ./requirements.txt (line 9)) (2.1.1)
# Requirement already satisfied: attrs>=17.3.0 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from aiohttp->gradio->-r ./requirements.txt (line 9)) (22.1.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from aiohttp->gradio->-r ./requirements.txt (line 9)) (1.2.0)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from aiohttp->gradio->-r ./requirements.txt (line 9)) (4.0.2)
# Requirement already satisfied: multidict<7.0,>=4.5 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from aiohttp->gradio->-r ./requirements.txt (line 9)) (6.0.2)
# Requirement already satisfied: yarl<2.0,>=1.0 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from aiohttp->gradio->-r ./requirements.txt (line 9)) (1.8.1)
# Requirement already satisfied: frozenlist>=1.1.1 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from aiohttp->gradio->-r ./requirements.txt (line 9)) (1.3.1)
# Requirement already satisfied: starlette==0.22.0 in /root/venv/lib/python3.9/site-packages (from fastapi->gradio->-r ./requirements.txt (line 9)) (0.22.0)
# Requirement already satisfied: typing-extensions>=3.10.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from starlette==0.22.0->fastapi->gradio->-r ./requirements.txt (line 9)) (4.4.0)
# Requirement already satisfied: anyio<5,>=3.4.0 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from starlette==0.22.0->fastapi->gradio->-r ./requirements.txt (line 9)) (3.6.2)
# Requirement already satisfied: rfc3986[idna2008]<2,>=1.3 in /root/venv/lib/python3.9/site-packages (from httpx->gradio->-r ./requirements.txt (line 9)) (1.5.0)
# Requirement already satisfied: httpcore<0.17.0,>=0.15.0 in /root/venv/lib/python3.9/site-packages (from httpx->gradio->-r ./requirements.txt (line 9)) (0.16.3)
# Requirement already satisfied: certifi in /shared-libs/python3.9/py/lib/python3.9/site-packages (from httpx->gradio->-r ./requirements.txt (line 9)) (2022.9.24)
# Requirement already satisfied: sniffio in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from httpx->gradio->-r ./requirements.txt (line 9)) (1.3.0)
# Requirement already satisfied: mdurl~=0.1 in /root/venv/lib/python3.9/site-packages (from markdown-it-py[linkify,plugins]->gradio->-r ./requirements.txt (line 9)) (0.1.2)
# Requirement already satisfied: linkify-it-py~=1.0 in /root/venv/lib/python3.9/site-packages (from markdown-it-py[linkify,plugins]->gradio->-r ./requirements.txt (line 9)) (1.0.3)
# Requirement already satisfied: mdit-py-plugins in /root/venv/lib/python3.9/site-packages (from markdown-it-py[linkify,plugins]->gradio->-r ./requirements.txt (line 9)) (0.3.3)
# Requirement already satisfied: idna<4,>=2.5 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from requests->folium->-r ./requirements.txt (line 4)) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from requests->folium->-r ./requirements.txt (line 4)) (1.26.12)
# Requirement already satisfied: joblib>=1.0.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from scikit-learn->mapclassify->-r ./requirements.txt (line 6)) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from scikit-learn->mapclassify->-r ./requirements.txt (line 6)) (3.1.0)
# Requirement already satisfied: h11>=0.8 in /root/venv/lib/python3.9/site-packages (from uvicorn->gradio->-r ./requirements.txt (line 9)) (0.14.0)
# Requirement already satisfied: click>=7.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from uvicorn->gradio->-r ./requirements.txt (line 9)) (8.1.3)
# Requirement already satisfied: pyrsistent>=0.14.0 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from jsonschema>=3.0->altair>=4.2.0->gradio->-r ./requirements.txt (line 9)) (0.18.1)
# Requirement already satisfied: setuptools in /root/venv/lib/python3.9/site-packages (from jsonschema>=3.0->altair>=4.2.0->gradio->-r ./requirements.txt (line 9)) (58.1.0)
# Requirement already satisfied: uc-micro-py in /root/venv/lib/python3.9/site-packages (from linkify-it-py~=1.0->markdown-it-py[linkify,plugins]->gradio->-r ./requirements.txt (line 9)) (1.0.1)
# WARNING: You are using pip version 22.0.4; however, version 22.3.1 is available.
# You should consider upgrading via the '/root/venv/bin/python -m pip install --upgrade pip' command.

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=1783b84c-867d-4124-84ad-5bf327fda65d' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
